# %%
# %run -i batch_run.py
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# Running small datasets without dimension reduction...
# Fitting model on dataset Stats features, center channels
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
# %run result_refine.py
# Out:
# /tmp/working/data/results/grid_run1/test_result.csv
# /tmp/working/data/results/grid_run1/cv_result.csv
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
# parse error
